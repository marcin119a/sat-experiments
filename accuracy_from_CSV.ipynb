# %%
import pandas as pd
import numpy as np

df = pd.read_csv('logs_1000_20200407(7)(1).csv', names=['M','alfa','y_hat','y_acc', 'TIME'], sep=',')

print(accuracy(df['y_acc'], df['y_hat']))

print(np.mean(df['TIME']))
print(sum(df['TIME'])/60)

len(df['y_hat'])
# Out:
# 0.659
# 22.810568891525268
# 380.1761481920878
# 1000

# %% [markdown]
# ### Eksperyment dla modelu:
#
# Wykorzystałem generowanie zbioru testowego z pracy:

# %%
def accuracy(x, y):
  return sum(1 for a,b in zip(x,y) if a == b) / len(x)

import collections

ConfusionMatrix = collections.namedtuple('ConfusionMatrix', 'name age gender')

def perf_measure(y_actual, y_hat):
    TP = 0
    FP = 0
    TN = 0
    FN = 0
    
    for i in range(len(y_hat)): 
        if y_actual[i]==y_hat[i]==1:
           TP += 1
        if y_hat[i]==1 and y_actual[i]!=y_hat[i]:
           FP += 1
        if y_actual[i]==y_hat[i]==0:
           TN += 1
        if y_hat[i]==0 and y_actual[i]!=y_hat[i]:
           FN += 1
    
    return (TP, FP, TN, FN)

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt


import pandas as pd

print(accuracy(df['y_acc'], df['y_hat']))
print()


TP, FP, TN, FN = perf_measure(df['y_acc'], df['y_hat'])

array = [[TP, FP], [FN, TN]]
df_cm = pd.DataFrame(array, index = [i for i in ["Y_hat=1","Y_hat=0"]],
                  columns = [i for i in ["Y_acc=1", "Y_acc=0"]])

sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, fmt="d", annot_kws={"size": 16}) # font size

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# 0.659

# %%
from sklearn.metrics import confusion_matrix

c = confusion_matrix(df['y_acc'], df['y_hat'])

# %%
from sklearn.metrics import classification_report
y_true = df['y_actual']
y_pred = df['y_hat']
target_names = ['sat=1', 'unsat=0']

print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#        sat=1       1.00      0.55      0.71       756
#      unsat=0       0.42      1.00      0.59       244
#
#     accuracy                           0.66      1000
#    macro avg       0.71      0.77      0.65      1000
# weighted avg       0.86      0.66      0.68      1000

# %%
df.plot.scatter(x='alfa', y='TIME')
df.plot.scatter(x='alfa', y='y_acc')
df.plot.scatter(x='alfa', y='y_hat')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
import numpy as np; np.random.seed(0)
import matplotlib.pyplot as plt
import pandas as pd

df3 = pd.DataFrame({'M/n':df['alfa']})

print(np.linspace(0, 2))
plt.hist(df3.values, bins=np.linspace(0, 2, 100), edgecolor="k")


plt.show()
# Out:
# [0.         0.04081633 0.08163265 0.12244898 0.16326531 0.20408163
#  0.24489796 0.28571429 0.32653061 0.36734694 0.40816327 0.44897959
#  0.48979592 0.53061224 0.57142857 0.6122449  0.65306122 0.69387755
#  0.73469388 0.7755102  0.81632653 0.85714286 0.89795918 0.93877551
#  0.97959184 1.02040816 1.06122449 1.10204082 1.14285714 1.18367347
#  1.2244898  1.26530612 1.30612245 1.34693878 1.3877551  1.42857143
#  1.46938776 1.51020408 1.55102041 1.59183673 1.63265306 1.67346939
#  1.71428571 1.75510204 1.79591837 1.83673469 1.87755102 1.91836735
#  1.95918367 2.        ]

# %%
np.linspace(0, 2, 100)
# Out:
# array([0.  , 0.02, 0.04, 0.06, 0.08, 0.1 , 0.12, 0.14, 0.16, 0.18, 0.2 ,
#        0.22, 0.24, 0.26, 0.28, 0.3 , 0.32, 0.34, 0.36, 0.38, 0.4 , 0.42,
#        0.44, 0.46, 0.48, 0.51, 0.53, 0.55, 0.57, 0.59, 0.61, 0.63, 0.65,
#        0.67, 0.69, 0.71, 0.73, 0.75, 0.77, 0.79, 0.81, 0.83, 0.85, 0.87,
#        0.89, 0.91, 0.93, 0.95, 0.97, 0.99, 1.01, 1.03, 1.05, 1.07, 1.09,
#        1.11, 1.13, 1.15, 1.17, 1.19, 1.21, 1.23, 1.25, 1.27, 1.29, 1.31,
#        1.33, 1.35, 1.37, 1.39, 1.41, 1.43, 1.45, 1.47, 1.49, 1.52, 1.54,
#        1.56, 1.58, 1.6 , 1.62, 1.64, 1.66, 1.68, 1.7 , 1.72, 1.74, 1.76,
#        1.78, 1.8 , 1.82, 1.84, 1.86, 1.88, 1.9 , 1.92, 1.94, 1.96, 1.98,
#        2.  ])

# %%
import pandas as pd
import numpy as np 

df = pd.read_csv('logs_10000_20200408(2).csv', names=['M','alfa','y_hat','y_acc', 'TIME'], sep=',')

#print(accuracy(df['y_actual'], df['y_hat']))

print(np.mean(df['TIME'])/60)
#print((df['TIME'])/60)

len(df['y_hat'])
# Out:
# 27.133236288362077
# 6
